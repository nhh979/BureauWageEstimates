# %%
import pandas as pd
import numpy as np

# %%
description = pd.read_excel("all_data_M_2022.xlsx", sheet_name=1, header=9, usecols=[0, 1])

# %%
description
# Out:
#                                                 Field  \
# 0                                                area
# 1                                          area_title
# 2                                           area_type
# 3                                          prim_state
# 4                                               naics
# 5                                         naics_title
# 6                                             i_group
# 7                                            own_code
# 8                                            occ_code
# 9                                           occ_title
# 10                                            o_group
# 11                                            tot_emp
# 12                                           emp_prse
# 13                                          jobs_1000
# 14                                       loc quotient
# 15                                          pct_total
# ...

# %%
df = pd.read_csv("all_data_M_2022.csv", dtype={'NAICS':'object'})
# Out:
# C:\Users\hoang\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13,14,15,16,30,31) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.shape
# Out:
# (409859, 32)

# %%
df.loc[df['OCC_TITLE'].str.contains("Manicurist")]
# Out:
#            AREA                                    AREA_TITLE  AREA_TYPE  \
# 770          99                                          U.S.          1
# 2151         99                                          U.S.          1
# 10306        99                                          U.S.          1
# 12544        99                                          U.S.          1
# 13316        99                                          U.S.          1
# ...         ...                                           ...        ...
# 389441  4200002    Northern Pennsylvania nonmetropolitan area          6
# 389442  4200003    Southern Pennsylvania nonmetropolitan area          6
# 389443  5300006       Western Washington nonmetropolitan area          6
# 389444  5500002   Northeastern Wisconsin nonmetropolitan area          6
# 389445  5500003  South Central Wisconsin nonmetropolitan area          6
#
#        PRIM_STATE   NAICS                                        NAICS_TITLE  \
# ...

# %%
with pd.option_context('display.max_rows', None):
    display(df[['NAICS', 'NAICS_TITLE']].drop_duplicates())
# Out:
#          NAICS                                        NAICS_TITLE
# 0       000000                                     Cross-industry
# 1402    000001             Cross-industry, private ownership only
# 2777        11         Agriculture, Forestry, Fishing and Hunting
# 3107        21      Mining, Quarrying, and Oil and Gas Extraction
# 3616        22                                          Utilities
# 4139        23                                       Construction
# 4903        42                                    Wholesale Trade
# 5833        51                                        Information
# 6488        52                              Finance and Insurance
# 7057        53                 Real Estate and Rental and Leasing
# 7693        54   Professional, Scientific, and Technical Services
# 8741        55            Management of Companies and Enterprises
# 9694        56  Administrative and Support and Waste Managemen...
# ...

# %%
with pd.option_context('display.max_rows', None):
    display(df.groupby(['NAICS', 'NAICS_TITLE'], as_index=True)['OCC_TITLE'].count().to_frame())
# Out:
#                                                            OCC_TITLE
# NAICS  NAICS_TITLE
# 000000 Cross-industry                                         235414
# 000001 Cross-industry, private ownership only                   1375
# 11     Agriculture, Forestry, Fishing and Hunting                330
# 113000 Forestry and Logging                                      120
# 113300 Logging                                                   120
# 115000 Support Activities for Agriculture and Forestry           308
# 115100 Support Activities for Crop Production                    268
# 115200 Support Activities for Animal Production                  166
# 21     Mining, Quarrying, and Oil and Gas Extraction             509
# 211000 Oil and Gas Extraction                                    328
# 211100 Oil and Gas Extraction                                    328
# 212000 Mining (except Oil and Gas)                               358
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409859 entries, 0 to 409858
# Data columns (total 32 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   AREA          409859 non-null  int64
#  1   AREA_TITLE    409859 non-null  object
#  2   AREA_TYPE     409859 non-null  int64
#  3   PRIM_STATE    409859 non-null  object
#  4   NAICS         409859 non-null  object
#  5   NAICS_TITLE   409859 non-null  object
#  6   I_GROUP       409859 non-null  object
#  7   OWN_CODE      409859 non-null  int64
#  8   OCC_CODE      409859 non-null  object
#  9   OCC_TITLE     409859 non-null  object
#  10  O_GROUP       409859 non-null  object
#  11  TOT_EMP       409859 non-null  object
#  12  EMP_PRSE      409859 non-null  object
#  13  JOBS_1000     234012 non-null  object
#  14  LOC_QUOTIENT  234012 non-null  object
#  15  PCT_TOTAL     168772 non-null  object
#  16  PCT_RPT       168772 non-null  object
# ...
